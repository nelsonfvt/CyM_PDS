# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import padasip as pa

# %% [markdown]
# Generando una señal sintética

# %%
N = 10000
n = np.arange(0,N)
xn = 0.5 * np.sin(2.0*np.pi*1.0/4.0*n) - 2.0 * np.sin(2.0*np.pi*1.0/8.0*n) + 1.5 * np.sin(2.0*np.pi*1.0/32.0*n)
plt.figure(1)
plt.stem(n[0:99],xn[0:99])
plt.xlabel('muestras')
plt.ylabel('Amplitud')
plt.show()

# %% [markdown]
# Adicionando ruido aleatorio a la señal sintética

# %%
fact_ruido = 0.05
xnr = xn + fact_ruido*np.random.normal(0,1,N)
plt.figure(2)
plt.stem(n[0:99],xnr[0:99])
plt.xlabel('muestras')
plt.ylabel('Amplitud')
plt.show()

# %% [markdown]
# Filtro adaptativo NLMS con padasip

# %%
ord = 20
pas = 0.8
# log
err = np.zeros(N-ord)
yn = np.zeros(N-ord) 
# filtro
flt = pa.filters.FilterNLMS(n=ord, mu=pas)
for i in range(0,N-ord):
    flt.adapt(xn[i], xnr[i:i+ord])
    yn[i] = flt.predict(xnr[i:i+ord])
    err[i] = xn[i] - yn[i]

# Parte real e imaginaria
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.set_title('Salida del filtro')
ax1.stem(yn[0:100],linefmt='red')
ax1.set_xlabel('muestras')
ax2.set_title('Error')
ax2.stem(err[0:100],linefmt='blue')
ax2.set_xlabel('muestras')

y = signal.lfilter(flt.w, 1, xnr)

# %% [markdown]
# Aplicación de medidas de calidad

# %%
from math import log10, sqrt

def PSNR(original, filtrada, max = 255.0):
    mse = np.mean((original - filtrada) ** 2)
    if(mse == 0):  # MSE is zero means no noise is present in the signal .
                  # Therefore PSNR have no importance.
        return 100
    psnr = 20 * log10(max / sqrt(mse))
    return psnr

# %% [markdown]
# Medidas...

# %%
p_pre = PSNR(xn[ord:N-ord],xnr[ord:N-ord],np.max(xn))
print(p_pre)
p_pos = PSNR(xn[ord:N-ord],yn[ord:N-ord],np.max(xn))
print(p_pos)
# Out:
# 36.63807626288684
# 43.27720741839872
