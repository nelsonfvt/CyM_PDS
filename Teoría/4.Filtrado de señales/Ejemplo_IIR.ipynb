# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# %% [markdown]
# Ejemplo de diseño y aplicación de filtros digitales (IIR)
#
# Inicialmente se crea una señal de prueba con varios armónicos para observar el desempeño de los filtros
#
# También se calcula su espectro de frecuencia usando la FFT

# %%
n = np.arange(0,512)
k = n/512
xn=np.sin(2*np.pi*n*1/4)+np.sin(2*np.pi*n*1/8)+np.sin(2*np.pi*n*1/32)+np.sin(2*np.pi*n*1/128)
Xk = abs(np.fft.fft(xn))

# Graficos

#señal
plt.figure(1)
plt.stem(n,xn)
plt.xlabel('muestras')
plt.ylabel('Amplitud')

#magnitud del espectro
plt.figure(2)
plt.stem(k,Xk)
plt.xlabel('Frec. Normalizada')
plt.ylabel('Amplitud armónicos')
plt.show()

# %% [markdown]
# Diseño de filtro IIR pasa-bajos mediante método de Butterworth
#
# Frecuencia de corte 1/32 ciclos/muestra (frec. normalizada)

# %%
cut = 1.0/16.0
b1, a1 = signal.butter(3,cut)

# Rta impulsional
nt, yi = signal.dimpulse((b1, a1, 1), n= 70)
plt.figure(1)
plt.stem(nt,np.squeeze(yi))
plt.title('Rta impulsiona IIR')
plt.ylabel('Amplitud')
plt.xlabel('muestras')
plt.show()

# %%
#Respuesta en frecuencia del filtro FIR
w, h = signal.freqz(b1,a1)
fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w, 20 * np.log10(abs(h)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [rad/sample]')
ax2 = ax1.twinx()
angles = np.unwrap(np.angle(h))
ax2.plot(w, angles, 'g')
ax2.set_ylabel('Angle (radians)', color='g')
ax2.grid(True)
ax2.axis('tight')
plt.show()

# %%
# Filtrar la señal con el filtro obtenido
y1n = signal.lfilter(b1,a1,xn)
plt.figure()
plt.stem(n,y1n)
plt.xlabel('muestras')
plt.ylabel('Amplitud')
plt.title('Señal filtrada')

plt.figure()
plt.stem(k,abs(np.fft.fft(y1n)))
plt.xlabel('Frec. Normalizada')
plt.ylabel('Amplitud armónicos')
plt.show()

# %% [markdown]
# Obteniendo filtro IIR usando la funcion cheby1.
#
# Diseño de filtro IIR pasa-bajos
#
# Frecuencia de corte 1/32 ciclos/muestra (frec. normalizada)

# %%
b2, a2 = signal.cheby1(3,0.5,cut)

# Rta impulsional
nt, yi = signal.dimpulse((b2, a2, 1), n= 70)
plt.figure(1)
plt.stem(nt,np.squeeze(yi))
plt.title('Rta impulsiona IIR')
plt.ylabel('Amplitud')
plt.xlabel('muestras')
plt.show()

# %%
#Respuesta en frecuencia del filtro IIR
w, h = signal.freqz(b2,a2)
fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w, 20 * np.log10(abs(h)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [rad/sample]')
ax2 = ax1.twinx()
angles = np.unwrap(np.angle(h))
ax2.plot(w, angles, 'g')
ax2.set_ylabel('Angle (radians)', color='g')
ax2.grid(True)
ax2.axis('tight')
plt.show()

# %%
# Filtrar la señal con el filtro obtenido
y2n = signal.lfilter(b2,a2,xn)
plt.figure()
plt.stem(n,y2n)
plt.xlabel('muestras')
plt.ylabel('Amplitud')
plt.title('Señal filtrada')

plt.figure()
plt.stem(k,abs(np.fft.fft(y2n)))
plt.xlabel('Frec. Normalizada')
plt.ylabel('Amplitud armónicos')
plt.show()

# %% [markdown]
# Obteniendo filtro IIR usando la funcion cheby2.
#
# Diseño de filtro IIR pasa-bajos
#
# Frecuencia de corte 1/32 ciclos/muestra (frec. normalizada)

# %%
b3, a3 = signal.cheby2(3,20,cut)

# Rta impulsional
nt, yi = signal.dimpulse((b3, a3, 1), n= 70)
plt.figure(1)
plt.stem(nt,np.squeeze(yi))
plt.title('Rta impulsiona IIR')
plt.ylabel('Amplitud')
plt.xlabel('muestras')
plt.show()

# %%
#Respuesta en frecuencia del filtro IIR
w, h = signal.freqz(b3,a3)
fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w, 20 * np.log10(abs(h)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [rad/sample]')
ax2 = ax1.twinx()
angles = np.unwrap(np.angle(h))
ax2.plot(w, angles, 'g')
ax2.set_ylabel('Angle (radians)', color='g')
ax2.grid(True)
ax2.axis('tight')
plt.show()

# %%
# Filtrar la señal con el filtro obtenido
y3n = signal.lfilter(b3,a3,xn)
plt.figure()
plt.stem(n,y3n)
plt.xlabel('muestras')
plt.ylabel('Amplitud')
plt.title('Señal filtrada')

plt.figure()
plt.stem(k,abs(np.fft.fft(y3n)))
plt.xlabel('Frec. Normalizada')
plt.ylabel('Amplitud armónicos')
plt.show()

# %% [markdown]
# Obteniendo filtro IIR usando la funcion ellip.
#
# Diseño de filtro IIR pasa-bajos
#
# Frecuencia de corte 1/32 ciclos/muestra (frec. normalizada)

# %%
b4, a4 = signal.ellip(3, 0.5 ,20 ,cut)

# Rta impulsional
nt, yi = signal.dimpulse((b4, a4, 1), n= 70)
plt.figure(1)
plt.stem(nt,np.squeeze(yi))
plt.title('Rta impulsiona IIR')
plt.ylabel('Amplitud')
plt.xlabel('muestras')
plt.show()

# %%
#Respuesta en frecuencia del filtro IIR
w, h = signal.freqz(b4,a4)
fig, ax1 = plt.subplots()
ax1.set_title('Digital filter frequency response')
ax1.plot(w, 20 * np.log10(abs(h)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [rad/sample]')
ax2 = ax1.twinx()
angles = np.unwrap(np.angle(h))
ax2.plot(w, angles, 'g')
ax2.set_ylabel('Angle (radians)', color='g')
ax2.grid(True)
ax2.axis('tight')
plt.show()

# %%
# Filtrar la señal con el filtro obtenido
y4n = signal.lfilter(b4,a4,xn)
plt.figure()
plt.stem(n,y4n)
plt.xlabel('muestras')
plt.ylabel('Amplitud')
plt.title('Señal filtrada')

plt.figure()
plt.stem(k,abs(np.fft.fft(y4n)))
plt.xlabel('Frec. Normalizada')
plt.ylabel('Amplitud armónicos')
plt.show()

# %% [markdown]
# Compare el desempeño de los filtros.
#
# Analice en el dominio de la frecuencia cerca de la frecuencia de corte.
#
# ¿Cómo se puede determinar cuál de los cuatro filtros es mejor?
